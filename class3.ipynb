# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/delinai/schulich_ds1/main/Datasets/kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
#what are the catergories of hmem that we have
#How can we classify them? (family homes, luxury, rural)
#What conditions would we use too classify the homes?
#If anything was renovated or built after 2000, then new, otherwise old

# %%
df.iloc[:, :11].describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000

# %%
df.iloc[:, 11:].describe()
# Out:
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
df.iloc[:,2:].corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# sqft_basement  0.323816  0.303093   0.283770     0.435043  0.015286 -0.245705
# yr_built       0.054012  0.154178   0.506019     0.318049  0.053080  0.489319
# yr_renovated   0.126434  0.018841   0.050739     0.055363  0.007644  0.006338
# zipcode       -0.053203 -0.152668  -0.203866    -0.199430 -0.129574 -0.059121
# lat            0.307003 -0.008931   0.024573     0.052529 -0.085683  0.049614
# long           0.021626  0.129473   0.223042     0.240223  0.229521  0.125419
# sqft_living15  0.585379  0.391638   0.568634     0.756420  0.144608  0.279885
# sqft_lot15     0.082447  0.029244   0.087175     0.183286  0.718557 -0.011269
#
#                waterfront      view  condition     grade  sqft_above  \
# price            0.266369  0.397293   0.036362  0.667434    0.605567
# bedrooms        -0.006582  0.079532   0.028472  0.356967    0.477600
# bathrooms        0.063744  0.187737  -0.124982  0.664983    0.685342
# sqft_living      0.103818  0.284611  -0.058753  0.762704    0.876597
# sqft_lot         0.021604  0.074710  -0.008958  0.113621    0.183512
# floors           0.023698  0.029444  -0.263768  0.458183    0.523885
# waterfront       1.000000  0.401857   0.016653  0.082775    0.072075
# view             0.401857  1.000000   0.045990  0.251321    0.167649
# condition        0.016653  0.045990   1.000000 -0.144674   -0.158214
# grade            0.082775  0.251321  -0.144674  1.000000    0.755923
# sqft_above       0.072075  0.167649  -0.158214  0.755923    1.000000
# sqft_basement    0.080588  0.276947   0.174105  0.168392   -0.051943
# yr_built        -0.026161 -0.053440  -0.361417  0.446963    0.423898
# yr_renovated     0.092885  0.103917  -0.060618  0.014414    0.023285
# zipcode          0.030285  0.084827   0.003026 -0.184862   -0.261190
# lat             -0.014274  0.006157  -0.014941  0.114084   -0.000816
# long            -0.041910 -0.078400  -0.106500  0.198372    0.343803
# sqft_living15    0.086463  0.280439  -0.092824  0.713202    0.731870
# sqft_lot15       0.030703  0.072575  -0.003406  0.119248    0.194050
#
#                sqft_basement  yr_built  yr_renovated   zipcode       lat  \
# price               0.323816  0.054012      0.126434 -0.053203  0.307003
# bedrooms            0.303093  0.154178      0.018841 -0.152668 -0.008931
# bathrooms           0.283770  0.506019      0.050739 -0.203866  0.024573
# sqft_living         0.435043  0.318049      0.055363 -0.199430  0.052529
# sqft_lot            0.015286  0.053080      0.007644 -0.129574 -0.085683
# floors             -0.245705  0.489319      0.006338 -0.059121  0.049614
# waterfront          0.080588 -0.026161      0.092885  0.030285 -0.014274
# view                0.276947 -0.053440      0.103917  0.084827  0.006157
# condition           0.174105 -0.361417     -0.060618  0.003026 -0.014941
# grade               0.168392  0.446963      0.014414 -0.184862  0.114084
# sqft_above         -0.051943  0.423898      0.023285 -0.261190 -0.000816
# sqft_basement       1.000000 -0.133124      0.071323  0.074845  0.110538
# yr_built           -0.133124  1.000000     -0.224874 -0.346869 -0.148122
# yr_renovated        0.071323 -0.224874      1.000000  0.064357  0.029398
# zipcode             0.074845 -0.346869      0.064357  1.000000  0.267048
# lat                 0.110538 -0.148122      0.029398  0.267048  1.000000
# long               -0.144765  0.409356     -0.068372 -0.564072 -0.135512
# sqft_living15       0.200355  0.326229     -0.002673 -0.279033  0.048858
# sqft_lot15          0.017276  0.070958      0.007854 -0.147221 -0.086419
#
#                    long  sqft_living15  sqft_lot15
# price          0.021626       0.585379    0.082447
# bedrooms       0.129473       0.391638    0.029244
# bathrooms      0.223042       0.568634    0.087175
# sqft_living    0.240223       0.756420    0.183286
# sqft_lot       0.229521       0.144608    0.718557
# floors         0.125419       0.279885   -0.011269
# waterfront    -0.041910       0.086463    0.030703
# view          -0.078400       0.280439    0.072575
# condition     -0.106500      -0.092824   -0.003406
# grade          0.198372       0.713202    0.119248
# sqft_above     0.343803       0.731870    0.194050
# sqft_basement -0.144765       0.200355    0.017276
# yr_built       0.409356       0.326229    0.070958
# yr_renovated  -0.068372      -0.002673    0.007854
# zipcode       -0.564072      -0.279033   -0.147221
# lat           -0.135512       0.048858   -0.086419
# long           1.000000       0.334605    0.254451
# sqft_living15  0.334605       1.000000    0.183192
# sqft_lot15     0.254451       0.183192    1.000000

# %%
#start by number of bedrooms - between 2-4 is standard, >4 large home, <2 small home
sns.boxplot(x='bedrooms', y='price', data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.boxplot(x='bathrooms', y='price', data=df)
# Out:
# <Axes: xlabel='bathrooms', ylabel='price'>

# %%
sns.boxplot(x='bedrooms', y='sqft_living', data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='sqft_living'>

# %%
sns.scatterplot(x='sqft_living', y='sqft_lot', data=df)
# Out:
# <Axes: xlabel='sqft_living', ylabel='sqft_lot'>

# %%
df['df_lot_to_living_ratio'] =df['sqft_lot'] / df['sqft_living']

# %%
df['price_per_sqft'] = df['price'] / df['sqft_living']

# %%
sns.boxplot(y='price_per_sqft', data=df)
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df.groupby('zipcode')['price_per_sqft'].mean()
# Out:
# zipcode
# 98001    151.387938
# 98002    151.174091
# 98003    157.113414
# 98004    475.435611
# 98005    314.929231
#             ...
# 98177    292.918745
# 98178    189.172528
# 98188    169.007306
# 98198    178.428610
# 98199    376.546345
# Name: price_per_sqft, Length: 70, dtype: float64

# %%
#start by number of bedrooms - between 2-4 is standard, >4 large home, <2 small home
#grade >

# %%
#avg price per sqft by zipcode
price_per_sqft = df.groupby('zipcode')['price_per_sqft'].mean().to_dict()

# %%
sns.boxplot(x='zipcode',y='price_per_sqft',data=df)
# Out:
# <Axes: xlabel='zipcode', ylabel='price_per_sqft'>

# %%
df.groupby('zipcode')['price'].sum()
# Out:
# zipcode
# 98001    101651298.0
# 98002     46622523.0
# 98003     82351158.0
# 98004    429828885.0
# 98005    136107699.0
#             ...
# 98177    172427275.0
# 98178     81380542.0
# 98188     39314655.0
# 98198     84806087.0
# 98199    251007196.0
# Name: price, Length: 70, dtype: float64

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,10))
sns.boxplot(x='zipcode',y='price_per_sqft',data=df[df['waterfront']==1], ax=ax1)
sns.boxplot(x='zipcode',y='price_per_sqft',data=df[df['waterfront']==0], ax=ax2)
# Out:
# <Axes: xlabel='zipcode', ylabel='price_per_sqft'>

# %%
#comparison with the same y-axis
ig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,10), sharey=True)
sns.boxplot(x='zipcode',y='price_per_sqft',data=df[df['waterfront']==1], ax=ax1)
sns.boxplot(x='zipcode',y='price_per_sqft',data=df[df['waterfront']==0], ax=ax2)
# Out:
# <Axes: xlabel='zipcode', ylabel='price_per_sqft'>

# %%
df.sort_values('zipcode')
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 11553  4031700030  20150410T000000  299999.0         3       2.50
# 18935  3353404265  20141231T000000  460000.0         3       2.50
# 16355  2214800170  20150415T000000  295000.0         3       2.50
# 6819    304100010  20141209T000000  269500.0         4       2.25
# 18933  7696620100  20150422T000000  254999.0         3       1.00
# ...           ...              ...       ...       ...        ...
# 10834   871000435  20150509T000000  812000.0         4       2.00
# 10909  1370803925  20140903T000000  535000.0         2       2.00
# 15505  6823100225  20150414T000000  700000.0         4       1.75
# 10969  3271300955  20140703T000000  554729.0         4       2.50
# 3112   5035300750  20140731T000000  850000.0         3       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_basement  \
# 11553         2380      9719     2.0           0     0  ...              0
# 18935         2720     40813     2.0           0     0  ...              0
# 16355         1940     10350     1.0           0     0  ...            520
# 6819          1700      7056     2.0           0     0  ...              0
# 18933         1580      7560     1.0           0     0  ...            580
# ...            ...       ...     ...         ...   ...  ...            ...
# 10834         2380      6122     1.0           0     2  ...           1070
# 10909         1510      5133     1.5           0     0  ...              0
# 15505         1870      6000     1.0           0     0  ...            200
# 10969         2020      4350     2.0           0     0  ...            290
# 3112          2450      8603     1.0           0     0  ...           1110
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 11553      2001             0    98001  47.2932 -122.283           2830
# 18935      2001             0    98001  47.2619 -122.271           2250
# 16355      1979             0    98001  47.3385 -122.256           1810
# 6819       1999             0    98001  47.3385 -122.262           1650
# 18933      1976             0    98001  47.3318 -122.277           1580
# ...         ...           ...      ...      ...      ...            ...
# 10834      1949             0    98199  47.6506 -122.405           1810
# 10909      1939             0    98199  47.6415 -122.401           1470
# 15505      1949             0    98199  47.6435 -122.399           1710
# 10969      1943             0    98199  47.6503 -122.410           1620
# 3112       1940             0    98199  47.6536 -122.414           2280
#
#        sqft_lot15  df_lot_to_living_ratio  price_per_sqft
# 11553       11505                4.083613      126.050000
# 18935       40511               15.004779      169.117647
# 16355        7800                5.335052      152.061856
# 6819         6025                4.150588      158.529412
# 18933        7560                4.784810      161.391772
# ...           ...                     ...             ...
# 10834        5202                2.572269      341.176471
# 10909        6000                3.399338      354.304636
# 15505        6000                3.208556      374.331551
# 10969        5800                2.153465      274.618317
# 3112         5779                3.511429      346.938776
#
# [21613 rows x 23 columns]

# %%
#we can use the mao function to map the average price to each value in the column(like vlookup)
df['avg_price_per_sqt'] = df['zipcode'].map(price_per_sqft)

# %%
df.sort_values('zipcode')
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 11553  4031700030  20150410T000000  299999.0         3       2.50
# 18935  3353404265  20141231T000000  460000.0         3       2.50
# 16355  2214800170  20150415T000000  295000.0         3       2.50
# 6819    304100010  20141209T000000  269500.0         4       2.25
# 18933  7696620100  20150422T000000  254999.0         3       1.00
# ...           ...              ...       ...       ...        ...
# 10834   871000435  20150509T000000  812000.0         4       2.00
# 10909  1370803925  20140903T000000  535000.0         2       2.00
# 15505  6823100225  20150414T000000  700000.0         4       1.75
# 10969  3271300955  20140703T000000  554729.0         4       2.50
# 3112   5035300750  20140731T000000  850000.0         3       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  yr_built  \
# 11553         2380      9719     2.0           0     0  ...      2001
# 18935         2720     40813     2.0           0     0  ...      2001
# 16355         1940     10350     1.0           0     0  ...      1979
# 6819          1700      7056     2.0           0     0  ...      1999
# 18933         1580      7560     1.0           0     0  ...      1976
# ...            ...       ...     ...         ...   ...  ...       ...
# 10834         2380      6122     1.0           0     2  ...      1949
# 10909         1510      5133     1.5           0     0  ...      1939
# 15505         1870      6000     1.0           0     0  ...      1949
# 10969         2020      4350     2.0           0     0  ...      1943
# 3112          2450      8603     1.0           0     0  ...      1940
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 11553             0    98001  47.2932 -122.283           2830       11505
# 18935             0    98001  47.2619 -122.271           2250       40511
# 16355             0    98001  47.3385 -122.256           1810        7800
# 6819              0    98001  47.3385 -122.262           1650        6025
# 18933             0    98001  47.3318 -122.277           1580        7560
# ...             ...      ...      ...      ...            ...         ...
# 10834             0    98199  47.6506 -122.405           1810        5202
# 10909             0    98199  47.6415 -122.401           1470        6000
# 15505             0    98199  47.6435 -122.399           1710        6000
# 10969             0    98199  47.6503 -122.410           1620        5800
# 3112              0    98199  47.6536 -122.414           2280        5779
#
#        df_lot_to_living_ratio  price_per_sqft  avg_price_per_sqt
# 11553                4.083613      126.050000         151.387938
# 18935               15.004779      169.117647         151.387938
# 16355                5.335052      152.061856         151.387938
# 6819                 4.150588      158.529412         151.387938
# 18933                4.784810      161.391772         151.387938
# ...                       ...             ...                ...
# 10834                2.572269      341.176471         376.546345
# 10909                3.399338      354.304636         376.546345
# 15505                3.208556      374.331551         376.546345
# 10969                2.153465      274.618317         376.546345
# 3112                 3.511429      346.938776         376.546345
#
# [21613 rows x 24 columns]

# %%
# store as a new dataframe and join instead
price_per_sqft_frame = df.groupby('zipcode')['price_per_sqft'].mean().to_frame()

# %%
new_df = pd.merge(df, price_per_sqft_frame, left_on = 'zipcode', right_on='zipcode')

# %%
new_df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  yr_renovated  \
# 0             1180      5650     1.0           0     0  ...             0
# 1             2570      7242     2.0           0     0  ...          1991
# 2              770     10000     1.0           0     0  ...             0
# 3             1960      5000     1.0           0     0  ...             0
# 4             1680      8080     1.0           0     0  ...             0
# ...            ...       ...     ...         ...   ...  ...           ...
# 21608         1530      1131     3.0           0     0  ...             0
# 21609         2310      5813     2.0           0     0  ...             0
# 21610         1020      1350     2.0           0     0  ...             0
# 21611         1600      2388     2.0           0     0  ...             0
# 21612         1020      1076     2.0           0     0  ...             0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0        98178  47.5112 -122.257           1340        5650
# 1        98125  47.7210 -122.319           1690        7639
# 2        98028  47.7379 -122.233           2720        8062
# 3        98136  47.5208 -122.393           1360        5000
# 4        98074  47.6168 -122.045           1800        7503
# ...        ...      ...      ...            ...         ...
# 21608    98103  47.6993 -122.346           1530        1509
# 21609    98146  47.5107 -122.362           1830        7200
# 21610    98144  47.5944 -122.299           1020        2007
# 21611    98027  47.5345 -122.069           1410        1287
# 21612    98144  47.5941 -122.299           1020        1357
#
#        df_lot_to_living_ratio  price_per_sqft_x  avg_price_per_sqt  \
# 0                    4.788136        188.050847         189.172528
# 1                    2.817899        209.338521         282.471664
# 2                   12.987013        233.766234         225.143085
# 3                    2.551020        308.163265         337.218034
# 4                    4.809524        303.571429         265.671342
# ...                       ...               ...                ...
# 21608                0.739216        235.294118         369.841013
# 21609                2.516450        173.160173         225.491431
# 21610                1.323529        394.216667         312.241854
# 21611                1.492500        250.000000         251.572289
# 21612                1.054902        318.627451         312.241854
#
#        price_per_sqft_y
# 0            189.172528
# 1            282.471664
# 2            225.143085
# 3            337.218034
# 4            265.671342
# ...                 ...
# 21608        369.841013
# 21609        225.491431
# 21610        312.241854
# 21611        251.572289
# 21612        312.241854
#
# [21613 rows x 25 columns]

# %%
# is the price above / below the average for the zipcode
df['above/below'] = df['price_per_sqft'] - df['avg_price_per_sqft']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'avg_price_per_sqft'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 2
#       1 # is the price above / below the average for the zipcode
# ----> 2 df['above/below'] = df['price_per_sqft'] - df['avg_price_per_sqft']
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'avg_price_per_sqft'

# %%
df['avg_sqft_for_area'] = df['zipcode'].map(df.groupby('zipcode')['sqft_living'].mean().to_dict())

# %%
df['above/below_sqft'] = df['sqft_living'] - df['avg_sqft_for_area']

# %%
def sale_category(row):
    # condition 1: if the house sold for less per sqft than the average price for the zipcode, AND the house was bigger than the avg size for the zipcode, then we got a value purchase
    if row["above/below_sqft"] < 0 and row['above/below_sqft'] > 0:
        return "value sale"
    # condition 2: if the house sold for less per sqft than the avg price for the zipcode, OR the house was bigger than avg for the area, then not necessarily a deal, but good outcome
    elif row["above/below_sqft"] < 0 or row['above/below_sqft'] > 0:
        return "avegare sale"
    # if neither was met, house is overpriced
    else:
        return "overpriced"

# %%
df['sale_value'] = df.apply(sale_category, axis=1)

# %%
#dealing with missing values
df2 = pd.read_csv('https://raw.githubusercontent.com/delinai/schulich_ds1_2024/main/Datasets/class2_sample_dataset.csv')

# %%
df2
# Out:
#      id   age         salary           city  experience  department
# 0     1  56.0   21864.850000        Nw York          33  Operations
# 1     2  69.0   29498.270000        Chicago           5     Finance
# 2     3  46.0   59544.580000        Chicago          19  Operations
# 3     4  32.0            NaN  San Francisco           4          IT
# 4     5  60.0   57140.640000  San Francisco          35          HR
# ..  ...   ...            ...            ...         ...         ...
# 95   96  42.0   50984.740000    Los Angeles          39     Finance
# 96   97  62.0  255192.192222       New York           5     Finance
# 97   98  58.0   63099.750000  San Francisco          22     Finance
# 98   99  46.0   53084.750000        Chicago          29     Finance
# 99  100  32.0   28347.750000  San Francisco           3          IT
#
# [100 rows x 6 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   age         90 non-null     float64
#  2   salary      92 non-null     float64
#  3   city        91 non-null     object
#  4   experience  100 non-null    int64
#  5   department  100 non-null    object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 4.8+ KB

# %%
#Why is the data missing
#MCAR = data misssing completely at random (no particular segragation of data for analysis), MAR = Data missing AT random (no pattern associated on why data is missing), MNAR = Data missing NOT at random

# %%
df2[df2.city.isnull()]['salary'].mean()
# Out:
# 47403.23714285714

# %%
df2.groupby('city')['salary'].mean()
# Out:
# city
# Chicago          58053.367346
# Los Angeles      75837.098963
# New York         70744.525222
# Nw York          52600.087778
# San Francisco    56301.341304
# Name: salary, dtype: float64

# %%
#If 10% of your total dataset has missing data you can drop the row

# %%
# %of missing data per column
df2.isnull().sum()/100
# Out:
# id            0.00
# age           0.10
# salary        0.08
# city          0.09
# experience    0.00
# department    0.00
# dtype: float64

# %%
df2.isnull().sum().sum() / df2.size
# Out:
# 0.045

# %%
df2.isnull().sum().sum() / df2.drop('id', axis=1).size
# Out:
# 0.054

# %%
df2.size
# Out:
# 600

# %%
df2
# Out:
#      id   age         salary           city  experience  department
# 0     1  56.0   21864.850000        Nw York          33  Operations
# 1     2  69.0   29498.270000        Chicago           5     Finance
# 2     3  46.0   59544.580000        Chicago          19  Operations
# 3     4  32.0            NaN  San Francisco           4          IT
# 4     5  60.0   57140.640000  San Francisco          35          HR
# ..  ...   ...            ...            ...         ...         ...
# 95   96  42.0   50984.740000    Los Angeles          39     Finance
# 96   97  62.0  255192.192222       New York           5     Finance
# 97   98  58.0   63099.750000  San Francisco          22     Finance
# 98   99  46.0   53084.750000        Chicago          29     Finance
# 99  100  32.0   28347.750000  San Francisco           3          IT
#
# [100 rows x 6 columns]

# %%
df2.describe(include='all')
# Out:
#                 id        age         salary           city  experience  \
# count   100.000000  90.000000      92.000000             91  100.000000
# unique         NaN        NaN            NaN              5         NaN
# top            NaN        NaN            NaN  San Francisco         NaN
# freq           NaN        NaN            NaN             27         NaN
# mean     50.500000  44.111111   61930.020664            NaN   21.220000
# std      29.011492  15.169043   49068.536745            NaN   11.350771
# min       1.000000  19.000000   20901.330000            NaN    1.000000
# 25%      25.750000  32.000000   38496.567500            NaN   12.750000
# 50%      50.500000  42.500000   51621.040000            NaN   23.000000
# 75%      75.250000  57.750000   63346.867500            NaN   31.000000
# max     100.000000  69.000000  255192.192222            NaN   39.000000
#
#        department
# count         100
# unique          4
# top       Finance
# freq           29
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# example of dropping data points
df2.dropna().describe(include='all')
# Out:
#                 id        age         salary           city  experience  \
# count    76.000000  76.000000      76.000000             76   76.000000
# unique         NaN        NaN            NaN              5         NaN
# top            NaN        NaN            NaN  San Francisco         NaN
# freq           NaN        NaN            NaN             21         NaN
# mean     53.144737  44.723684   63919.643436            NaN   22.039474
# std      28.928281  15.785731   53220.816385            NaN   11.278819
# min       1.000000  19.000000   20901.330000            NaN    1.000000
# 25%      28.750000  31.750000   39036.797500            NaN   14.500000
# 50%      56.500000  44.000000   50703.115000            NaN   23.000000
# 75%      76.250000  59.250000   63517.910000            NaN   32.000000
# max     100.000000  69.000000  255192.192222            NaN   39.000000
#
#         department
# count           76
# unique           4
# top     Operations
# freq            23
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %%
# filling in with constant value
df2['city'] = df2['city'].fillna('Unknown')

# %%
df2.groupby('city').count()
# Out:
#                id  age  salary  experience  department
# city
# Chicago        19   16      18          19          19
# Los Angeles    15   13      15          15          15
# New York       20   19      20          20          20
# Nw York        10    8       9          10          10
# San Francisco  27   25      23          27          27
# Unknown         9    9       7           9           9

# %%
df2['age'] = df2['age'].fillna(df2['age'].median())

# %%
df2.head()
# Out:
#    id   age    salary           city  experience  department
# 0   1  56.0  21864.85        Nw York          33  Operations
# 1   2  69.0  29498.27        Chicago           5     Finance
# 2   3  46.0  59544.58        Chicago          19  Operations
# 3   4  32.0       NaN  San Francisco           4          IT
# 4   5  60.0  57140.64  San Francisco          35          HR

# %%
#salary - missing at randim, varies by city
df2.groupby('city')['salary'].transform('mean')
# Out:
# 0     52600.087778
# 1     58053.367346
# 2     58053.367346
# 3     56301.341304
# 4     56301.341304
#           ...
# 95    75837.098963
# 96    70744.525222
# 97    56301.341304
# 98    58053.367346
# 99    56301.341304
# Name: salary, Length: 100, dtype: float64

# %%
#salary - missing at randim, varies by city
df2.groupby('city')['salary'].fillna(df2.groupby('city')['salary'].transform('mean'))
# Out:
# /var/folders/95/mkx4bvf95x35657hmtzpc5fr0000gn/T/ipykernel_3636/89412966.py:2: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   df2.groupby('city')['salary'].fillna(df2.groupby('city')['salary'].transform('mean'))
# 0      21864.850000
# 1      29498.270000
# 2      59544.580000
# 3      56301.341304
# 4      57140.640000
#           ...
# 95     50984.740000
# 96    255192.192222
# 97     63099.750000
# 98     53084.750000
# 99     28347.750000
# Name: salary, Length: 100, dtype: float64

# %%
df2['city'] = df2['city'].replace('Nw York', 'New York')

# %%
df2.groupby('city').count()
# Out:
#                id  age  salary  experience  department
# city
# Chicago        19   19      18          19          19
# Los Angeles    15   15      15          15          15
# New York       30   30      29          30          30
# San Francisco  27   27      23          27          27
# Unknown         9    9       7           9           9
