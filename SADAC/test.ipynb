# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df =pd.read_csv('https://raw.githubusercontent.com/ggotoo/schulich_data_science/main/SADAC/gravity_database_sadc_tradesample%20-%20Sheet1.csv')

# %%
df.head()
# Out:
#    year country_o iso3_o dynamic_code_o      country_d iso3_d dynamic_code_d  \
# 0  2015    Angola    AGO            AGO  Cote d'Ivoire    CIV            CIV
# 1  2016    Angola    AGO            AGO  Cote d'Ivoire    CIV            CIV
# 2  2017    Angola    AGO            AGO  Cote d'Ivoire    CIV            CIV
# 3  2018    Angola    AGO            AGO  Cote d'Ivoire    CIV            CIV
# 4  2019    Angola    AGO            AGO  Cote d'Ivoire    CIV            CIV
#
#    colony_of_destination_ever  colony_of_origin_ever  colony_ever  ...  \
# 0                           0                      0            0  ...
# 1                           0                      0            0  ...
# 2                           0                      0            0  ...
# 3                           0                      0            0  ...
# 4                           0                      0            0  ...
#
#    afcfta_o_39  afcfta_o_71  afcfta_o_72  afcfta_o_73  afcfta_o_74  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Columns: 189 entries, year to afcfta_o_87
# dtypes: float64(98), int64(33), object(58)
# memory usage: 325.0+ KB

# %%
df.isnull().sum()/100
# Out:
# year              0.00
# country_o         0.00
# iso3_o            0.00
# dynamic_code_o    0.00
# country_d         0.00
#                   ...
# afcfta_o_75       0.50
# afcfta_o_76       0.50
# afcfta_o_84       1.65
# afcfta_o_85       0.80
# afcfta_o_87       0.60
# Length: 189, dtype: float64

# %%
df = df.drop(columns=['sanction_threat_trade', 'sanction_threat', 'imp_o_98', 'sanction_imposition_trade', 'sanction_imposition', 'hostility_level_o', 'hostility_level_d'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Columns: 182 entries, year to afcfta_o_87
# dtypes: float64(91), int64(33), object(58)
# memory usage: 312.9+ KB

# %%
df.head()
# Out:
#    year country_o iso3_o dynamic_code_o      country_d iso3_d dynamic_code_d  \
# 0  2015    Angola    AGO            AGO  Cote d'Ivoire    CIV            CIV
# 1  2016    Angola    AGO            AGO  Cote d'Ivoire    CIV            CIV
# 2  2017    Angola    AGO            AGO  Cote d'Ivoire    CIV            CIV
# 3  2018    Angola    AGO            AGO  Cote d'Ivoire    CIV            CIV
# 4  2019    Angola    AGO            AGO  Cote d'Ivoire    CIV            CIV
#
#    colony_of_destination_ever  colony_of_origin_ever  colony_ever  ...  \
# 0                           0                      0            0  ...
# 1                           0                      0            0  ...
# 2                           0                      0            0  ...
# 3                           0                      0            0  ...
# 4                           0                      0            0  ...
#
#    afcfta_o_39  afcfta_o_71  afcfta_o_72  afcfta_o_73  afcfta_o_74  \
# ...

# %%
for column in df.columns:
    if df[column].dtype in ['float64', 'int64']:
        df[column].fillna(df[column].median(), inplace=True)
    else:
        df[column].fillna(df[column].mode()[0], inplace=True)
# Out:
# /var/folders/95/mkx4bvf95x35657hmtzpc5fr0000gn/T/ipykernel_56302/2043304038.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].median(), inplace=True)
# /var/folders/95/mkx4bvf95x35657hmtzpc5fr0000gn/T/ipykernel_56302/2043304038.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Columns: 182 entries, year to afcfta_o_87
# dtypes: float64(91), int64(33), object(58)
# memory usage: 312.9+ KB
